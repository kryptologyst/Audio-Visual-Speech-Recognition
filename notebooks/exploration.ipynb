# %% [markdown]
# # Audio-Visual Speech Recognition Exploration
#
# This notebook provides an interactive exploration of the Audio-Visual Speech Recognition system.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# Import our modules
from src.models import AVConformer
from src.data import AVSpeechDataset
from src.utils import get_device, set_seed
from src.viz import plot_training_curves

# Set up
set_seed(42)
device = get_device()
print(f"Using device: {device}")
